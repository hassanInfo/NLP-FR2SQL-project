# %%
# !pip install -q -U datasets > /dev/null

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 16.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 42.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.2 transformers-4.24.0

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 15.0 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer
from datasets import load_dataset
import random, warnings
warnings.filterwarnings("ignore")

# %%
tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-wikiSQL")
model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-wikiSQL")
# Out:
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# The `xla_device` argument has been deprecated in v4.4.0 of Transformers. It is ignored and you can safely remove it from your `config.json` file.
# Downloading:   0%|          | 0.00/1.19G [00:00<?, ?B/s]

# %%
def get_sql(query):
    
    input_text = "translate English to SQL: %s </s>" % query
    
    features = tokenizer([input_text], return_tensors='pt')

    output = model.generate(input_ids=features['input_ids'], 
               attention_mask=features['attention_mask'])

    return tokenizer.decode(output[0])

# %%
valid_dataset = load_dataset('wikisql', split='validation')
# Out:
# Downloading builder script:   0%|          | 0.00/6.57k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.76k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.80k [00:00<?, ?B/s]
# Downloading and preparing dataset wikisql/default to /root/.cache/huggingface/datasets/wikisql/default/0.1.0/7037bfe6a42b1ca2b6ac3ccacba5253b1825d31379e9cc626fc79a620977252d...
# Downloading data:   0%|          | 0.00/26.2M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/15878 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/8421 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/56355 [00:00<?, ? examples/s]
# Dataset wikisql downloaded and prepared to /root/.cache/huggingface/datasets/wikisql/default/0.1.0/7037bfe6a42b1ca2b6ac3ccacba5253b1825d31379e9cc626fc79a620977252d. Subsequent calls will reuse this data.

# %%
valid_dataset[0]
# Out:
# {'phase': 1,
#  'question': 'What position does the player who played for butler cc (ks) play?',
#  'table': {'header': ['Player',
#    'No.',
#    'Nationality',
#    'Position',
#    'Years in Toronto',
#    'School/Club Team'],
#   'page_title': 'Toronto Raptors all-time roster',
#   'page_id': '',
#   'types': ['text', 'text', 'text', 'text', 'text', 'text'],
#   'id': '1-10015132-11',
#   'section_title': 'L',
#   'caption': 'L',
#   'rows': [['Antonio Lang',
#     '21',
#     'United States',
#     'Guard-Forward',
#     '1999-2000',
#     'Duke'],
#    ['Voshon Lenard', '2', 'United States', 'Guard', '2002-03', 'Minnesota'],
#    ['Martin Lewis',
#     '32, 44',
#     'United States',
#     'Guard-Forward',
#     '1996-97',
#     'Butler CC (KS)'],
#    ['Brad Lohaus', '33', 'United States', 'Forward-Center', '1996', 'Iowa'],
#    ['Art Long',
#     '42',
#     'United States',
#     'Forward-Center',
#     '2002-03',
#     'Cincinnati'],
#    ['John Long', '25', 'United States', 'Guard', '1996-97', 'Detroit'],
#    ['Kyle Lowry', '3', 'United States', 'Guard', '2012-Present', 'Villanova']],
#   'name': 'table_10015132_11'},
#  'sql': {'human_readable': 'SELECT Position FROM table WHERE School/Club Team = Butler CC (KS)',
#   'sel': 3,
#   'agg': 0,
#   'conds': {'column_index': [5],
#    'operator_index': [0],
#    'condition': ['Butler CC (KS)']}}}

# %%
for idx in random.sample(range(len(valid_dataset)), 250):
    print(f"Text: {valid_dataset[idx]['question']}")
    print(f"Pred SQL: {get_sql(valid_dataset[idx]['question'])}")
    print(f"True SQL: {valid_dataset[idx]['sql']['human_readable']}\n")
# Out:
# Text: Which Percentage has a Draw of 6?
# Pred SQL: <pad> SELECT Percentage FROM table WHERE Draw = 6</s>
# True SQL: SELECT Percentage FROM table WHERE Draw = 6
#
# Text: Who had the pole(s) when esteban guerrieri led the most laps round 8a and josef newgarden had the fastest lap?
# Pred SQL: <pad> SELECT Poles FROM table WHERE Most laps = esteban guerrier
# True SQL: SELECT Pole position FROM table WHERE Most laps led = Esteban Guerrieri AND Fastest lap = Josef Newgarden AND Rd. = 8A
#
# Text: What is the season # for a teleplay by Richard Price and the director is Steve Shill?
# Pred SQL: <pad> SELECT Season # FROM table WHERE Directed by = Steve Shill AND
# True SQL: SELECT Season # FROM table WHERE Teleplay by = Richard Price AND Directed by = Steve Shill
#
# Text: What is the capacity of code f4r?
# Pred SQL: <pad> SELECT Capacity FROM table WHERE Code = f4r</s>
# True SQL: SELECT Capacity FROM table WHERE Code = f4r
#
# Text: Which venue hosted a home team with a score of 13.15 (93)?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Home team score = 13.15 (93)</s>
# True SQL: SELECT Venue FROM table WHERE Home team score = 13.15 (93)
#
# Text: What is the high lap total for cards with a grid larger than 21, and a Time/Retired of +2 laps?
# Pred SQL: <pad> SELECT MAX Laps FROM table WHERE Grid > 21 AND Time/
# True SQL: SELECT MAX Laps FROM table WHERE Grid > 21 AND Time/Retired = +2 laps
#
# Text: When did Philoxenus Anicetus begin to hold power?
# Pred SQL: <pad> SELECT First elected FROM table WHERE Name = philoxenus an
# True SQL: SELECT From FROM table WHERE Name = philoxenus anicetus
#
# Text: When did chatham complete the Hmsmedusa?
# Pred SQL: <pad> SELECT Date FROM table WHERE Team = Chatham</s>
# True SQL: SELECT Completed FROM table WHERE Builder = chatham AND Name = hmsmedusa
#
# Text: What is the Season with a Big Ten that is 2nd (386)?
# Pred SQL: <pad> SELECT Season FROM table WHERE Big Ten = 2nd (386)</s>
# True SQL: SELECT Season FROM table WHERE Big Ten = 2nd (386)
#
# Text: Who reported the game played on 1 september?
# Pred SQL: <pad> SELECT Report FROM table WHERE Date = 1 september</s>
# True SQL: SELECT Report FROM table WHERE Date = 1 september
#
# Text: I want to know the drawn that has a tie of 0 and the player is chris cowdrey
# Pred SQL: <pad> SELECT Drawn FROM table WHERE Tie no = 0 AND Player =
# True SQL: SELECT Drawn FROM table WHERE Tied = 0 AND Player = chris cowdrey
#
# Text: how many times is the nhl team the winnipeg jets?
# Pred SQL: <pad> SELECT COUNT Game FROM table WHERE NHL team = Winnipeg Jets</s>
# True SQL: SELECT COUNT Player FROM table WHERE NHL team = Winnipeg Jets
#
# Text: How many total show when silver is 0, bronze is 1, and the rank is less than 3?
# Pred SQL: <pad> SELECT COUNT Total FROM table WHERE Silver = 0 AND Bronze = 1
# True SQL: SELECT COUNT Total FROM table WHERE Silver = 0 AND Bronze = 1 AND Rank < 3
#
# Text: Which Venue is the one for the footscray Home team?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Home team = footscray</s>
# True SQL: SELECT Venue FROM table WHERE Home team = footscray
#
# Text: What is the Name of the dinosaur that was discovered in the Location, China, and whose Notes are, "described from a single tooth"?
# Pred SQL: <pad> SELECT Name FROM table WHERE Notes = described from a single tooth AND
# True SQL: SELECT Name FROM table WHERE Location = china AND Notes = described from a single tooth
#
# Text: Which Event has 5th Position in the European Championships Competition?
# Pred SQL: <pad> SELECT Event FROM table WHERE Position = 5th AND Competition = european championships
# True SQL: SELECT Event FROM table WHERE Competition = european championships AND Position = 5th
#
# Text: What is City of License, when Frequency MHz is less than 102.5?
# Pred SQL: <pad> SELECT City of license FROM table WHERE Frequency MHz <unk> 10
# True SQL: SELECT City of license FROM table WHERE Frequency MHz < 102.5
#
# Text: Which home team had the away team Southport?
# Pred SQL: <pad> SELECT Home team FROM table WHERE Away team = southport</s>
# True SQL: SELECT Home team FROM table WHERE Away team = southport
#
# Text: What was the earliest aired show that's returning on September 13?
# Pred SQL: <pad> SELECT MIN Air Date FROM table WHERE Return Date = September 13</s>
# True SQL: SELECT MIN Last Aired FROM table WHERE Returning = september 13
#
# Text: What is Country, when Total is greater than 283, and when Year(s) Won is "1989"?
# Pred SQL: <pad> SELECT Country FROM table WHERE Total > 283 AND Year(s) won
# True SQL: SELECT Country FROM table WHERE Total > 283 AND Year(s) won = 1989
#
# Text: How many total Rank listings have Liu Xiaosheng listed as the athlete with a react entry that is smaller than 0.245?
# Pred SQL: <pad> SELECT COUNT Rank FROM table WHERE Athlete = l
# True SQL: SELECT COUNT Rank FROM table WHERE Athlete = liu xiaosheng AND React < 0.245
#
# Text: What was the largest crowd to view a game where the away team scored 17.8 (110)?
# Pred SQL: <pad> SELECT MAX Crowd FROM table WHERE Away team score = 17.8
# True SQL: SELECT MAX Crowd FROM table WHERE Away team score = 17.8 (110)
#
# Text: If the losing bonus was 6, what is the tries for?
# Pred SQL: <pad> SELECT Tries for FROM table WHERE Losing bonus = 6</s>
# True SQL: SELECT Tries for FROM table WHERE Losing bonus = 6
#
# Text: Which venue did the away team score 12.10 (82)?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Away team score = 12.10 (82)</s>
# True SQL: SELECT Venue FROM table WHERE Away team score = 12.10 (82)
#
# Text: which round is u.s. open cup division semifinals
# Pred SQL: <pad> SELECT Round FROM table WHERE Division Finals = U.S. Open Cup
# True SQL: SELECT U.S. Open Cup FROM table WHERE Playoffs = Division Semifinals
#
# Text: The ship named Bacchus with a tonnage of t had what disposition of ship?
# Pred SQL: <pad> SELECT Disposition of Ship FROM table WHERE Tonnage = t AND Name
# True SQL: SELECT Disposition of Ship FROM table WHERE Tonnage = t AND Ship Name = bacchus
#
# Text: What is the largest region with a Code smaller than 66112, and a Name of l'île-dorval?
# Pred SQL: <pad> SELECT MAX Region FROM table WHERE Code <unk> 66112 AND Name
# True SQL: SELECT MAX Region FROM table WHERE Code < 66112 AND Name = l'île-dorval
#
# Text: What's the sum of all average yards gained when the gained yards is under 1,276 and lost more than 3 yards?
# Pred SQL: <pad> SELECT SUM Avg. Yards gained FROM table WHERE Yards
# True SQL: SELECT SUM Avg/G FROM table WHERE Gain < 1,276 AND Loss > 3
#
# Text: How many nationalities are there for the 2011 apertura?
# Pred SQL: <pad> SELECT COUNT Nationality FROM table WHERE 2011 = apertura</s>
# True SQL: SELECT COUNT Nationality FROM table WHERE Tournament = 2011 Apertura
#
# Text: What's the title for the release date of 1953-01-31 in the MM series, no reissue, and a director of I. Freleng?
# Pred SQL: <pad> SELECT Title FROM table WHERE Reissue = no AND Series = mm AND
# True SQL: SELECT Title FROM table WHERE Series = mm AND Director = i. freleng AND reissue? = no AND Release date = 1953-01-31
#
# Text: Which Season has an Opponent of hibernians?
# Pred SQL: <pad> SELECT Season FROM table WHERE Opponent = hibernians</s>
# True SQL: SELECT Season FROM table WHERE Opponent = hibernians
#
# Text: What is the average number of years on learners of the drivers over the age of 24 with less than 0 attempts at the licence test?
# Pred SQL: <pad> SELECT AVG Years on Learners FROM table WHERE Age > 24 AND At
# True SQL: SELECT AVG Years on learners FROM table WHERE Driver's Age > 24 AND Licence test attempts < 0
#
# Text: Who directed the episode with production code 4akj01?
# Pred SQL: <pad> SELECT Directed by FROM table WHERE Production code = 4AKJ01
# True SQL: SELECT Directed by FROM table WHERE Production code = 4AKJ01
#
# Text: What score did the home team of north melbourne get?
# Pred SQL: <pad> SELECT Home team score FROM table WHERE Home team = north melbourne</s>
# True SQL: SELECT Home team score FROM table WHERE Home team = north melbourne
#
# Text: What is the sum of Goals, when Season is "2005-06", and when Division is less than 1?
# Pred SQL: <pad> SELECT SUM Goals FROM table WHERE Season = 2005-06 AND Division
# True SQL: SELECT SUM Goals FROM table WHERE Season = 2005-06 AND Division < 1
#
# Text: what is at 8:00 when at 8:30 it is my thursday night movie?
# Pred SQL: <pad> SELECT 8:00 FROM table WHERE 8:30 = my thursday night movie
# True SQL: SELECT 8:00 FROM table WHERE 8:30 = my thursday night movie
#
# Text: What is the Cook PVI for the location that has a representative of Mike Thompson?
# Pred SQL: <pad> SELECT Cook PVI FROM table WHERE Representative = mike tho
# True SQL: SELECT Cook PVI FROM table WHERE Representative = Mike Thompson
#
# Text: What was the date of the game when the Canadiens had a record of 31–19–9?
# Pred SQL: <pad> SELECT Date FROM table WHERE Record = 31–19–9</s>
# True SQL: SELECT Date FROM table WHERE Record = 31–19–9
#
# Text: On what Route is the mountain with a Rank less than 33 and an Elevation of 11,312 feet 3448 m?
# Pred SQL: <pad> SELECT Route FROM table WHERE Rank <unk> 33 AND Elevation (
# True SQL: SELECT MAX Route FROM table WHERE Rank < 33 AND Elevation = 11,312 feet 3448 m
#
# Text: Who was the game attended by 60425 people played against?
# Pred SQL: <pad> SELECT Opponent FROM table WHERE Attendance = 60425</s>
# True SQL: SELECT Opponent FROM table WHERE Attendance = 60425
#
# Text: Name the location attendance april 5
# Pred SQL: <pad> SELECT Location Attendance FROM table WHERE Date = April 5</s>
# True SQL: SELECT Location Attendance FROM table WHERE Date = April 5
#
# Text: Which loss has an attendance greater than 49,688 and 11-8 as the record?
# Pred SQL: <pad> SELECT Loss FROM table WHERE Attendance > 49,688 AND Record
# True SQL: SELECT Loss FROM table WHERE Attendance > 49,688 AND Record = 11-8
#
# Text: Which Score has an Opponent of @ houston, and a Record of 2-0?
# Pred SQL: <pad> SELECT Score FROM table WHERE Opponent = @ houston AND Record =
# True SQL: SELECT Score FROM table WHERE Opponent = @ houston AND Record = 2-0
#
# Text: What is the Team of Winner Mark Skaife in ATCC Round 7?
# Pred SQL: <pad> SELECT Team FROM table WHERE Winner = mark skaife AND Round =
# True SQL: SELECT Team FROM table WHERE Winner = mark skaife AND Series = atcc round 7
#
# Text: What is the Score of the game of the Player in Place 4?
# Pred SQL: <pad> SELECT Score FROM table WHERE Place = 4</s>
# True SQL: SELECT Score FROM table WHERE Place = 4
#
# Text: Where was the tournament played on Oct. 8, 2006?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Date = oct. 8, 2006</s>
# True SQL: SELECT Tournament FROM table WHERE Date = oct. 8, 2006
#
# Text: How many golds have 3 as the rank, with a total greater than 7?
# Pred SQL: <pad> SELECT SUM Gold FROM table WHERE Rank = 3 AND Total > 7
# True SQL: SELECT COUNT Gold FROM table WHERE Rank = 3 AND Total > 7
#
# Text: What position does Mario Kasun play?
# Pred SQL: <pad> SELECT Position FROM table WHERE Player = mario kasun</s>
# True SQL: SELECT Position FROM table WHERE Player = mario kasun
#
# Text: What are the bore & stroke specifications for an engine with 4-barrel carburetor and VIN code of A?
# Pred SQL: <pad> SELECT Bore & Stroke FROM table WHERE Carburet
# True SQL: SELECT Bore & Stroke FROM table WHERE Carburetor = 4-barrel AND VIN Code = a
#
# Text: What home team has a team score of 8.12 (60)?
# Pred SQL: <pad> SELECT Home team FROM table WHERE Home team score = 8.12 (60)
# True SQL: SELECT Home team FROM table WHERE Home team score = 8.12 (60)
#
# Text: What is the average Rank for a lane smaller than 3 with a nationality of Australia?
# Pred SQL: <pad> SELECT AVG Rank FROM table WHERE Lane <unk> 3 AND Nationality
# True SQL: SELECT AVG Rank FROM table WHERE Lane < 3 AND Nationality = australia
#
# Text: What is the average when the rank by average is more than 12?
# Pred SQL: <pad> SELECT AVG Average FROM table WHERE Rank by average > 12</s>
# True SQL: SELECT SUM Average FROM table WHERE Rank by average > 12
#
# Text: The episode with the title "Bait" has what original air date?
# Pred SQL: <pad> SELECT Original air date FROM table WHERE Title = "Bait"</s>
# True SQL: SELECT Original air date FROM table WHERE Title = "Bait"
#
# Text: In what venue was the hosted away team Essendon?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Away team = essendon</s>
# True SQL: SELECT Venue FROM table WHERE Away team = essendon
#
# Text: How many places have bianka panova as the name, with clubs less than 10?
# Pred SQL: <pad> SELECT COUNT Place FROM table WHERE Name = bianka panova AND
# True SQL: SELECT COUNT Place FROM table WHERE Name = bianka panova AND Clubs < 10
#
# Text: What is the date of the zolder circuit, which had a.z.k./roc-compétition a.z.k./roc-compétition as the winning team?
# Pred SQL: <pad> SELECT Date FROM table WHERE Winning team = a.z.k
# True SQL: SELECT Date FROM table WHERE Winning team = a.z.k./roc-compétition a.z.k./roc-compétition AND Circuit = zolder
#
# Text: Which date has a To par of –12?
# Pred SQL: <pad> SELECT Date FROM table WHERE To par = –12</s>
# True SQL: SELECT Date FROM table WHERE To par = –12
#
# Text: which playoffs took place during 2011?
# Pred SQL: <pad> SELECT Playoffs FROM table WHERE Year = 2011</s>
# True SQL: SELECT Playoffs FROM table WHERE Year = 2011
#
# Text: What location attendance has russell westbrook (5) as high assists and nenad krstic (8) as high rebounds?
# Pred SQL: <pad> SELECT Location Attendance FROM table WHERE High assists = russell westbrook
# True SQL: SELECT Location Attendance FROM table WHERE High assists = Russell Westbrook (5) AND High rebounds = Nenad Krstic (8)
#
# Text: What was the home team's score at the game attended by more than 24,637?
# Pred SQL: <pad> SELECT Home team score FROM table WHERE Attendance > 24,637</s>
# True SQL: SELECT Home team score FROM table WHERE Crowd > 24,637
#
# Text: Who manufactured grid 11?
# Pred SQL: <pad> SELECT Manufacturer FROM table WHERE Grid = 11</s>
# True SQL: SELECT Manufacturer FROM table WHERE Grid = 11
#
# Text: In the championship Miami , United States, what is the score in the final?
# Pred SQL: <pad> SELECT Score in the final FROM table WHERE Championship = Miami, United States
# True SQL: SELECT Score in the final FROM table WHERE Championship = Miami , United States
#
# Text: In how many different categories is the value of C_{low} 35.5?
# Pred SQL: <pad> SELECT COUNT Category FROM table WHERE C_<unk>low<unk> = 35.5
# True SQL: SELECT COUNT Category FROM table WHERE C_{low} = 35.5
#
# Text: What is the cyrillic and other name of rabe?
# Pred SQL: <pad> SELECT Cyrillic Name Other Names FROM table WHERE Greek Names
# True SQL: SELECT Cyrillic Name Other Names FROM table WHERE Settlement = Rabe
#
# Text: What is the height of the Tides with less than 34 floors?
# Pred SQL: <pad> SELECT Height FROM table WHERE Floors <unk> 34 AND Name = tides
# True SQL: SELECT Height feet / m FROM table WHERE Floors < 34 AND Name = the tides
#
# Text: Which Surname has Throws of l, and a DOB of 5/02/79?
# Pred SQL: <pad> SELECT Surname FROM table WHERE Throws = l AND DOB =
# True SQL: SELECT Surname FROM table WHERE Throws = l AND D.O.B. = 5/02/79
#
# Text: What position does Zack Torquato play?
# Pred SQL: <pad> SELECT Position FROM table WHERE Player = zack torquato</s>
# True SQL: SELECT Position FROM table WHERE Player = zack torquato
#
# Text: Give the earliest year that featured Pi Hongyan on women's singles.
# Pred SQL: <pad> SELECT MIN Year FROM table WHERE Women's singles = pi
# True SQL: SELECT MIN Year FROM table WHERE Women's singles = pi hongyan
#
# Text: Who won the mixed restricted when Tomasz Rzeszotko won the mixed veteran and Karina Le Fevre won the U21 womens?
# Pred SQL: <pad> SELECT Mixed restricted FROM table WHERE Mixed veteran = tomasz rze
# True SQL: SELECT Mixed Restricted FROM table WHERE Mixed Veteran = Tomasz Rzeszotko AND U21 Womens = Karina Le Fevre
#
# Text: What is the total number of points of the honda hr-1 engine?
# Pred SQL: <pad> SELECT COUNT Points FROM table WHERE Engine = honda hr
# True SQL: SELECT COUNT Points FROM table WHERE Engine = honda hr-1
#
# Text: How many cuts did the player who earned 210408 Euro make?
# Pred SQL: <pad> SELECT Cuts made FROM table WHERE Euros earned = 210408</s>
# True SQL: SELECT Cuts made FROM table WHERE Earnings (€) = 210408
#
# Text: Who played against in venue a on 17 february 1900?
# Pred SQL: <pad> SELECT Opponent FROM table WHERE Venue = a AND Date = 17 febr
# True SQL: SELECT Opponent FROM table WHERE Venue = a AND Date = 17 february 1900
#
# Text: Which week was the game on December 14, 1967?
# Pred SQL: <pad> SELECT Week FROM table WHERE Date = december 14, 1967</s>
# True SQL: SELECT Week FROM table WHERE Date = december 14, 1967
#
# Text: Tell me the highest wins for year less than 2000 and best finish of 4 and tournaments played less than 3
# Pred SQL: <pad> SELECT MAX Wins FROM table WHERE Year <unk> 2000 AND Best Finish
# True SQL: SELECT MAX Wins FROM table WHERE Year < 2000 AND Best finish = 4 AND Tournaments played < 3
#
# Text: What College has a Player that is jermaine romans?
# Pred SQL: <pad> SELECT College FROM table WHERE Player = jermaine romans</s>
# True SQL: SELECT College FROM table WHERE Player = jermaine romans
#
# Text: what is the mountain peak when the location is 37.5775°n 105.4856°w?
# Pred SQL: <pad> SELECT Mountain Peak FROM table WHERE Location = 37.5775°n
# True SQL: SELECT Mountain Peak FROM table WHERE Location = 37.5775°n 105.4856°w
#
# Text: Name the place for score of 67-70=137 and stuart appleby
# Pred SQL: <pad> SELECT Place FROM table WHERE Score = 67-70=137 AND Player
# True SQL: SELECT Place FROM table WHERE Score = 67-70=137 AND Player = stuart appleby
#
# Text: Name the pinyin for mazar
# Pred SQL: <pad> SELECT Pinyin FROM table WHERE Name = mazar</s>
# True SQL: SELECT Pinyin FROM table WHERE Conventional = Mazar
#
# Text: What is Bronze, when Silver is 2, and when Nation is Italy?
# Pred SQL: <pad> SELECT Bronze FROM table WHERE Silver = 2 AND Nation = italy</s>
# True SQL: SELECT Bronze FROM table WHERE Silver = 2 AND Nation = italy
#
# Text: What is Height, when Rank is less than 20, when Floors is greater than 9, when Built is 2005, and when Name is The Edge (C)?
# Pred SQL: <pad> SELECT Height FROM table WHERE Rank <unk> 20 AND Floors > 9
# True SQL: SELECT Height FROM table WHERE Rank < 20 AND Floors > 9 AND Built = 2005 AND Name = the edge (c)
#
# Text: Which player has a Position of defence, and a Pick # of 6?
# Pred SQL: <pad> SELECT Player FROM table WHERE Position = defence AND Pick # = 6</s>
# True SQL: SELECT Player FROM table WHERE Position = defence AND Pick # = 6
#
# Text: List the weight for 56.5 kilograms.
# Pred SQL: <pad> SELECT Weight FROM table WHERE Kilogram = 56.5</s>
# True SQL: SELECT Race FROM table WHERE Weight (kg) = 56.5
#
# Text: What is the Name of ङ ng/na?
# Pred SQL: <pad> SELECT Name FROM table WHERE Chinese = <unk> ng/na</s>
# True SQL: SELECT Name FROM table WHERE Pada 3 = ङ ng/na
#
# Text: Which Bullet diameter has a Neck diameter of 12.17 (.479)?
# Pred SQL: <pad> SELECT Bullet diameter FROM table WHERE Neck diameter = 12.17 (.479)
# True SQL: SELECT Bullet diameter FROM table WHERE Neck diameter = 12.17 (.479)
#
# Text: Which country has the catalog nr of thr-048 in 2004?
# Pred SQL: <pad> SELECT Country FROM table WHERE Catalog Nr = thr-048 AND
# True SQL: SELECT Country FROM table WHERE Date = 2004 AND Catalog Nr. = thr-048
#
# Text: What was the lamar hunt u.s. open cup when concacaf champions cup / concacaf champions league was did not qualify and mls regular season was 4th, central (11-16-5)?
# Pred SQL: <pad> SELECT LAMAR Hunt U.S. Open Cup FROM table WHERE Conca
# True SQL: SELECT Lamar Hunt U.S. Open Cup FROM table WHERE CONCACAF Champions Cup / CONCACAF Champions League = Did not qualify AND MLS Regular Season = 4th, Central (11-16-5)
#
# Text: What was their record on February 24?
# Pred SQL: <pad> SELECT Record FROM table WHERE Date = february 24</s>
# True SQL: SELECT Record FROM table WHERE Date = february 24
#
# Text: What is the enrollment for Ashland University?
# Pred SQL: <pad> SELECT Enrollment FROM table WHERE Institution = Ashland University</s>
# True SQL: SELECT Enrollment FROM table WHERE Location (all in Ohio) = Ashland
#
# Text: What is the competition at the ta'qali venue?
# Pred SQL: <pad> SELECT Competition FROM table WHERE Venue = ta'qali</s>
# True SQL: SELECT Competition FROM table WHERE Venue = ta'qali
#
# Text: What is the highest Legs Lost with a 180s larger than 1, a 100+ of 53, and played is smaller than 4?
# Pred SQL: <pad> SELECT MAX Legs Lost FROM table WHERE 180s > 1 AND 100
# True SQL: SELECT MAX Legs Lost FROM table WHERE 180s > 1 AND 100+ = 53 AND Played < 4
#
# Text: What is the wheel arrangement made in 1890?
# Pred SQL: <pad> SELECT Wheel arrangement FROM table WHERE Year made = 1890</s>
# True SQL: SELECT Wheel arrangement FROM table WHERE Year made = 1890
#
# Text: What is the loss for the game against @ expos, with a save of parrett (2)?
# Pred SQL: <pad> SELECT Loss FROM table WHERE Opponent = @ expos AND Save
# True SQL: SELECT Loss FROM table WHERE Opponent = @ expos AND Save = parrett (2)
#
# Text: Who received gold when the event is time trial details and silver is simon richardson great britain (gbr)?
# Pred SQL: <pad> SELECT Gold FROM table WHERE Event = time trial details AND Silver = simon
# True SQL: SELECT Gold FROM table WHERE Event = time trial details AND Silver = simon richardson great britain (gbr)
#
# Text: What town has the population of 777?
# Pred SQL: <pad> SELECT Town FROM table WHERE Population = 777</s>
# True SQL: SELECT Cyrillic Name Other Names FROM table WHERE Population (2011) = 777
#
# Text: What is the lowest Total containing a Bronze of 0 and Rank smaller than 2?
# Pred SQL: <pad> SELECT MIN Total FROM table WHERE Bronze = 0 AND Rank
# True SQL: SELECT MIN Total FROM table WHERE Bronze = 0 AND Rank < 2
#
# Text: What is the rear sight in the Cole model no. 735?
# Pred SQL: <pad> SELECT Rear sight FROM table WHERE Model no. = cole AND Model
# True SQL: SELECT Rear sight FROM table WHERE Colt model no. = 735
#
# Text: Name the money raised when 2Q has money spent and 2Q is $874,042
# Pred SQL: <pad> SELECT Money Raised FROM table WHERE Money Spent = 2Q AND 2
# True SQL: SELECT Money Raised, 2Q FROM table WHERE Money Spent, 2Q = $874,042
#
# Text: Who is the women's doubles when the mixed doubles are sudket prapakamol saralee thungthongkam?
# Pred SQL: <pad> SELECT Women's doubles FROM table WHERE Mixed doubles = Sudket
# True SQL: SELECT Womens doubles FROM table WHERE Mixed doubles = Sudket Prapakamol Saralee Thungthongkam
#
# Text: What was the home teams score while playing the away team of south melbourne?
# Pred SQL: <pad> SELECT Home team score FROM table WHERE Away team = south melbourne
# True SQL: SELECT Home team score FROM table WHERE Away team = south melbourne
#
# Text: What was the score of the Mariners game when they had a record of 56–21?
# Pred SQL: <pad> SELECT Score FROM table WHERE Record = 56–21</s>
# True SQL: SELECT Score FROM table WHERE Record = 56–21
#
# Text: What is the quantity preserved to the locomotive with a quantity made of 6?
# Pred SQL: <pad> SELECT Quantity preserved FROM table WHERE Quantity made = 6</s>
# True SQL: SELECT Quantity preserved FROM table WHERE Quantity made = 6
#
# Text: What place did Jimmy Reece start from when he ranked 12?
# Pred SQL: <pad> SELECT Start FROM table WHERE Rank = 12 AND Player = jim
# True SQL: SELECT Start FROM table WHERE Rank = 12
#
# Text: Who has the low lap total in a maserati with grid 2?
# Pred SQL: <pad> SELECT MIN Laps FROM table WHERE Constructor = mas
# True SQL: SELECT MIN Laps FROM table WHERE Constructor = maserati AND Grid = 2
#
# Text: What is the lowest Floors, when Built is greater than 1970, and when Name is NV Building 3?
# Pred SQL: <pad> SELECT MIN Floors FROM table WHERE Built > 1970 AND Name =
# True SQL: SELECT MIN Floors FROM table WHERE Built > 1970 AND Name = nv building 3
#
# Text: Which round 5 Grand Prix had Daijiro Hiura at pole position?
# Pred SQL: <pad> SELECT Round FROM table WHERE Pole Position = daijiro hiura AND
# True SQL: SELECT Grand Prix FROM table WHERE Pole Position = Daijiro Hiura AND Round = 5
#
# Text: What's the episode of Batman?
# Pred SQL: <pad> SELECT Episode FROM table WHERE Title = Batman</s>
# True SQL: SELECT Episode FROM table WHERE Program = batman
#
# Text: How much Loss has a Gain smaller than 1571, and a Long smaller than 47, and an Avg/G of 36.4?
# Pred SQL: <pad> SELECT SUM Loss FROM table WHERE Gain <unk> 1571 AND Long
# True SQL: SELECT COUNT Loss FROM table WHERE Gain < 1571 AND Long < 47 AND Avg/G = 36.4
#
# Text: Tell me the winning constructor for the paris cup
# Pred SQL: <pad> SELECT Winning constructor FROM table WHERE Competition = paris cup</s>
# True SQL: SELECT Winning constructor FROM table WHERE Name = paris cup
#
# Text: What season has a regionalliga süd league, a 1-0 home, and an away of 2-3?
# Pred SQL: <pad> SELECT Season FROM table WHERE League = regionalliga süd AND Home
# True SQL: SELECT Season FROM table WHERE League = regionalliga süd AND Home = 1-0 AND Away = 2-3
#
# Text: Name the number of party for richard l. hanna (r) 53.1% mike arcuri (d) 46.9%
# Pred SQL: <pad> SELECT COUNT Party FROM table WHERE Incumbent = Richard L. Hann
# True SQL: SELECT COUNT Party FROM table WHERE Candidates = Richard L. Hanna (R) 53.1% Mike Arcuri (D) 46.9%
#
# Text: How many rewards are there for air date October 6, 2005?
# Pred SQL: <pad> SELECT COUNT Rewards FROM table WHERE Air Date = October 6, 2005</s>
# True SQL: SELECT Reward FROM table WHERE Air date = October 6, 2005
#
# Text: Which Year is the lowest when the Viewers are 13.7 million?
# Pred SQL: <pad> SELECT MIN Year FROM table WHERE Viewers = 13.7 million</s>
# True SQL: SELECT MIN Year FROM table WHERE Viewers = 13.7 million
#
# Text: What is the Score with a Date that is 2008-06-28?
# Pred SQL: <pad> SELECT Score FROM table WHERE Date = 2008-06-28</s>
# True SQL: SELECT Score FROM table WHERE Date = 2008-06-28
#
# Text: What is the name of the Representative Work in a year later than 2005 with a Result of nominated, and an Award of best variety show host?
# Pred SQL: <pad> SELECT Representative Work FROM table WHERE Year > 2005 AND Result = nomin
# True SQL: SELECT Representative Work FROM table WHERE Year > 2005 AND Result = nominated AND Award = best variety show host
#
# Text: What position is Justin Shaw in?
# Pred SQL: <pad> SELECT Position FROM table WHERE Player = justin shaw</s>
# True SQL: SELECT Position FROM table WHERE Player = Justin Shaw
#
# Text: WHAT IS THE RATING THAT HAD A SHARE SMALLER THAN 4, AND 2.47 MILLION VIEWERS?
# Pred SQL: <pad> SELECT Rating FROM table WHERE Share <unk> 4 AND Viewers = 2.47
# True SQL: SELECT COUNT Rating FROM table WHERE Share < 4 AND Viewers (millions) > 2.47
#
# Text: What was the final score for the tie where Leeds United was the home team?
# Pred SQL: <pad> SELECT Final Score FROM table WHERE Home team = leeds united</s>
# True SQL: SELECT Score FROM table WHERE Home team = leeds united
#
# Text: Who was the away team at the game at Victoria Park?
# Pred SQL: <pad> SELECT Away team FROM table WHERE Venue = victoria park</s>
# True SQL: SELECT Away team FROM table WHERE Venue = victoria park
#
# Text: what is the material of the surface in the dehradun , uttarakhand, india location
# Pred SQL: <pad> SELECT Material FROM table WHERE Location = dehradun, u
# True SQL: SELECT Surface FROM table WHERE Location = Dehradun , Uttarakhand, India
#
# Text: What is the Fri 3 June time for the rider with a Weds 1 June time of 18' 22.66 123.182mph?
# Pred SQL: <pad> SELECT Fri 3 June FROM table WHERE Wed 1 June = 18' 22
# True SQL: SELECT Fri 3 June FROM table WHERE Wed 1 June = 18' 22.66 123.182mph
#
# Text: How many in total were elected first in lost renomination?
# Pred SQL: <pad> SELECT COUNT First elected FROM table WHERE Result = Lost reno
# True SQL: SELECT COUNT First elected FROM table WHERE Result = Lost renomination
#
# Text: What was the score of the game when the record was 39–21–4?
# Pred SQL: <pad> SELECT Score FROM table WHERE Record = 39–21–4</s>
# True SQL: SELECT Score FROM table WHERE Record = 39–21–4
#
# Text: What's the release date of Forward March Hare?
# Pred SQL: <pad> SELECT Release date FROM table WHERE Title = forward march hare</s>
# True SQL: SELECT Release date FROM table WHERE Title = forward march hare
#
# Text: Which of the biggest points numbers had a year more recent than 1953?
# Pred SQL: <pad> SELECT MAX Points FROM table WHERE Year > 1953</s>
# True SQL: SELECT MAX Points FROM table WHERE Year > 1953
#
# Text: When Tujunga is moderate, what is La Crescenta-Montrose?
# Pred SQL: <pad> SELECT La Crescenta-Montrose FROM table WHERE Tujunga =
# True SQL: SELECT La Crescenta- Montrose FROM table WHERE Tujunga = moderate
#
# Text: What position did Pranita Sahu's team get?
# Pred SQL: <pad> SELECT Position FROM table WHERE Player = pranita sa
# True SQL: SELECT Position FROM table WHERE Co-contestant (Yaar vs. Pyaar) = Pranita Sahu
#
# Text: What venue hosted the stan fox stakes?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Event = stan fox stakes</s>
# True SQL: SELECT Venue FROM table WHERE Race = stan fox stakes
#
# Text: Player of napoleon lajoie, and a Team of cleveland bronchos, and a Doubles of 49 which years record stood?
# Pred SQL: <pad> SELECT Years Record FROM table WHERE Player = napoleon lajo
# True SQL: SELECT Years Record Stood FROM table WHERE Player = napoleon lajoie AND Team = cleveland bronchos AND Doubles = 49
#
# Text: How many times was Mike McIntyre elected?
# Pred SQL: <pad> SELECT COUNT First elected FROM table WHERE Incumbent = Mike McIn
# True SQL: SELECT COUNT Results FROM table WHERE Incumbent = Mike McIntyre
#
# Text: What is the name for the 2008 club of Azs olsztyn?
# Pred SQL: <pad> SELECT Name FROM table WHERE 2008 club = azs ol
# True SQL: SELECT Name FROM table WHERE 2008 club = azs olsztyn
#
# Text: Name the number of seats to be won being % of popular vote at 6.88%
# Pred SQL: <pad> SELECT COUNT Seats to be won FROM table WHERE % of popular
# True SQL: SELECT # of seats to be won FROM table WHERE % of popular vote = 6.88%
#
# Text: What was the result on the 26th?
# Pred SQL: <pad> SELECT Result FROM table WHERE Date = 26th</s>
# True SQL: SELECT Result FROM table WHERE Date = 26th
#
# Text: What is the sum total of picks for drake players from the tri-cities blackhawks?
# Pred SQL: <pad> SELECT SUM Pick FROM table WHERE NHL team = tri-cities black
# True SQL: SELECT SUM Pick FROM table WHERE Team = tri-cities blackhawks AND College = drake
#
# Text: What is the earliest years any of the incumbents were first elected?
# Pred SQL: <pad> SELECT MIN First elected FROM table</s>
# True SQL: SELECT MIN First elected FROM table
#
# Text: Which Catalog was formated as a CD under the label Alfa Records?
# Pred SQL: <pad> SELECT Catalog FROM table WHERE Format = cd AND Label = alf
# True SQL: SELECT Catalog FROM table WHERE Label = alfa records AND Format = cd
#
# Text: What is the lowest pick that has arizona cardinals as the NFL club?
# Pred SQL: <pad> SELECT MIN Pick FROM table WHERE NFL Club = arizona card
# True SQL: SELECT MIN Pick FROM table WHERE NFL Club = arizona cardinals
#
# Text: How many races did he do in the year he had 8 points?
# Pred SQL: <pad> SELECT Races FROM table WHERE Points = 8</s>
# True SQL: SELECT Races FROM table WHERE Points = 8
#
# Text: WHich Studio analysts has a Studio host of gary tanguay in 2009-10?
# Pred SQL: <pad> SELECT Studio analysts FROM table WHERE Studio hosts = gary tangua
# True SQL: SELECT Studio analysts FROM table WHERE Studio host = gary tanguay AND Year = 2009-10
#
# Text: Which Opponent has a Score of 92-111?
# Pred SQL: <pad> SELECT Opponent FROM table WHERE Score = 92-111</s>
# True SQL: SELECT Opponent FROM table WHERE Score = 92-111
#
# Text: What is the total number of PLD for Team Arsenal?
# Pred SQL: <pad> SELECT COUNT PLD FROM table WHERE Team = arsenal</s>
# True SQL: SELECT COUNT Total Pld FROM table WHERE Team = arsenal
#
# Text: What is the Series with a High rebounds with gasol (10)?
# Pred SQL: <pad> SELECT Series FROM table WHERE High rebounds = gasol (10)</s>
# True SQL: SELECT Series FROM table WHERE High rebounds = gasol (10)
#
# Text: Name the resolution for dish of 5270
# Pred SQL: <pad> SELECT Resolution FROM table WHERE Dish = 5270</s>
# True SQL: SELECT Resolution FROM table WHERE Dish = 5270
#
# Text: What is Record, when Game is "24"?
# Pred SQL: <pad> SELECT Record FROM table WHERE Game = 24</s>
# True SQL: SELECT Record FROM table WHERE Game = 24
#
# Text: what is the year where glos & wilts is gloucester city winget?
# Pred SQL: <pad> SELECT Year FROM table WHERE Glos & Wilts = glo
# True SQL: SELECT Year FROM table WHERE Glos & Wilts = Gloucester City Winget
#
# Text: What races have gp2 series, 0 F.L. and a 17th position?
# Pred SQL: <pad> SELECT Races FROM table WHERE Series = gp2 AND F.
# True SQL: SELECT Races FROM table WHERE Series = gp2 series AND F.L. = 0 AND Position = 17th
#
# Text: What is the 20 year for Nitrous Oxide?
# Pred SQL: <pad> SELECT 20 year FROM table WHERE Substance = nitrous oxide</s>
# True SQL: SELECT 20-yr FROM table WHERE Gas name = Nitrous oxide
#
# Text: Can you tell me the Score that has the Result of win, and the Date of 13 november 2009?
# Pred SQL: <pad> SELECT Score FROM table WHERE Result = win AND Date = 13 nov
# True SQL: SELECT Score FROM table WHERE Result = win AND Date = 13 november 2009
#
# Text: What position did Max Redfield play?
# Pred SQL: <pad> SELECT Position FROM table WHERE Player = max redfield</s>
# True SQL: SELECT Position FROM table WHERE Player = max redfield
#
# Text: Which Date has a Competition of pl group b, and Opponents of police, and a Venue of selayang municipal council stadium?
# Pred SQL: <pad> SELECT Date FROM table WHERE Competition = pl group b AND Opponents
# True SQL: SELECT Date FROM table WHERE Competition = pl group b AND Opponents = police AND Venue = selayang municipal council stadium
#
# Text: What is the lowest number of gold medals the nation with less than 0 silver medals has?
# Pred SQL: <pad> SELECT MIN Gold FROM table WHERE Silver <unk> 0</s>
# True SQL: SELECT MIN Gold FROM table WHERE Silver < 0
#
# Text: Which Position has 47 Goals Against, and a Played larger than 34?
# Pred SQL: <pad> SELECT Position FROM table WHERE Goals Against = 47 AND Played
# True SQL: SELECT MAX Position FROM table WHERE Goals Against = 47 AND Played > 34
#
# Text: What day did they play at candlestick park?
# Pred SQL: <pad> SELECT Date FROM table WHERE Venue = candlestick park</s>
# True SQL: SELECT Date FROM table WHERE Game site = candlestick park
#
# Text: What's the total of rank 8 when Silver medals are 0 and gold is more than 1?
# Pred SQL: <pad> SELECT SUM Rank 8 FROM table WHERE Silver = 0 AND Gold
# True SQL: SELECT COUNT Total FROM table WHERE Silver = 0 AND Rank = 8 AND Gold > 1
#
# Text: Which Tie is from birmingham city?
# Pred SQL: <pad> SELECT Tie no FROM table WHERE Hometown = birmingham city
# True SQL: SELECT Tie no FROM table WHERE Home team = birmingham city
#
# Text: Which Crowd has an Away team score of 8.6 (54)?
# Pred SQL: <pad> SELECT SUM Crowd FROM table WHERE Away team score = 8.6
# True SQL: SELECT AVG Crowd FROM table WHERE Away team score = 8.6 (54)
#
# Text: What is Team, when Replaced By is "Jesús Ramírez"?
# Pred SQL: <pad> SELECT Team FROM table WHERE Replaced by = jes<unk>s ram
# True SQL: SELECT Team FROM table WHERE Replaced by = jesús ramírez
#
# Text: What is the title of the single with the peak position of 10 and weeks on chart is less than 19?
# Pred SQL: <pad> SELECT Title FROM table WHERE Peak position = 10 AND Weeks on chart
# True SQL: SELECT Title FROM table WHERE Peak position = 10 AND Weeks on chart < 19
#
# Text: What was the score in the year 2004?
# Pred SQL: <pad> SELECT Score FROM table WHERE Year = 2004</s>
# True SQL: SELECT Score FROM table WHERE Year = 2004
#
# Text: Which Lost is the highest one that has a Drawn smaller than 4, and a Played smaller than 9?
# Pred SQL: <pad> SELECT MAX Lost FROM table WHERE Drawn <unk> 4 AND Playe
# True SQL: SELECT MAX Lost FROM table WHERE Drawn < 4 AND Played < 9
#
# Text: What is the FSB / HT (MHz) when the Southbridge is amd-8131 amd-8132?
# Pred SQL: <pad> SELECT FSB / HT (MHz) FROM table WHERE South
# True SQL: SELECT FSB / HT (MHz) FROM table WHERE Southbridge = amd-8131 amd-8132
#
# Text: What is Dependencia Sexual's film title that was used in its nomination?
# Pred SQL: <pad> SELECT Film title used in nomination FROM table WHERE Director = Dependencia Sexual
# True SQL: SELECT Film title used in nomination FROM table WHERE Original title = dependencia sexual
#
# Text: What is the 2012 election results for locations whose representative is Barbara Lee?
# Pred SQL: <pad> SELECT 2012 election FROM table WHERE Representative = Barbara Lee</s>
# True SQL: SELECT 2012 election results FROM table WHERE Representative = Barbara Lee
#
# Text: Which driver is older than 24 and has more than 0 licence test attempts?
# Pred SQL: <pad> SELECT Driver FROM table WHERE License Test Try > 0 AND Age > 24
# True SQL: SELECT Learner driver FROM table WHERE Licence test attempts > 0 AND Driver's Age > 24
#
# Text: What Ad Freq has a News Freq of 60 minutes, and a Local/Networked of local?
# Pred SQL: <pad> SELECT Ad Freq FROM table WHERE News Freq = 60 minutes AND Local
# True SQL: SELECT Ad Freq FROM table WHERE News Freq = 60 minutes AND Local/Networked = local
#
# Text: What is the Place of the half marathon Event?
# Pred SQL: <pad> SELECT Place FROM table WHERE Event = half marathon</s>
# True SQL: SELECT Place FROM table WHERE Event = half marathon
#
# Text: In which county is the city/town of Halden located?
# Pred SQL: <pad> SELECT County FROM table WHERE City/Town = halden</s>
# True SQL: SELECT County FROM table WHERE City/town = Halden
#
# Text: What nationality is the player from Oregon State?
# Pred SQL: <pad> SELECT Nationality FROM table WHERE College = oregon state</s>
# True SQL: SELECT Nationality FROM table WHERE From = oregon state
#
# Text: When was Dickinson College founded?
# Pred SQL: <pad> SELECT Founded FROM table WHERE Institution = Dickinson College</s>
# True SQL: SELECT Founded FROM table WHERE Institution = Dickinson College
#
# Text: What is the FCC frequency for the station w262al which has a Frequency MHz larger than 92.7?
# Pred SQL: <pad> SELECT FCC Frequency MHz FROM table WHERE Frequency
# True SQL: SELECT FCC info FROM table WHERE Frequency MHz > 92.7 AND Call sign = w262al
#
# Text: What is the lowest Viewers that has an Episode #higher than 58 with a title of "curveball" less than 4.1 rating?
# Pred SQL: <pad> SELECT MIN Viewers FROM table WHERE Episode # > 58 AND Title
# True SQL: SELECT MIN Viewers FROM table WHERE Episode # > 58 AND Title = "curveball" AND Rating < 4.1
#
# Text: What is the date when internet explorer was 62.2%
# Pred SQL: <pad> SELECT Date FROM table WHERE Internet Explorer = 62.2%</s>
# True SQL: SELECT Date FROM table WHERE Internet Explorer = 62.2%
#
# Text: If the horizontal bar is n/a and the floor is 14.175, what is the number for the parallel bars?
# Pred SQL: <pad> SELECT Parallel bars FROM table WHERE Floor = 14.175 AND Horizontal bar
# True SQL: SELECT Parallel Bars FROM table WHERE Floor = 14.175 AND Horizontal Bar = N/A
#
# Text: What was the date of appointment for incoming manager Roy Hodgson and the team is Liverpool?
# Pred SQL: <pad> SELECT Date of appointment FROM table WHERE Incoming manager = roy hod
# True SQL: SELECT Date of appointment FROM table WHERE Team = Liverpool AND Incoming manager = Roy Hodgson
#
# Text: Which team was in the 2012 clausura tournament?
# Pred SQL: <pad> SELECT Team FROM table WHERE Tournament = 2012 clausura</s>
# True SQL: SELECT Team FROM table WHERE Tournament = 2012 Clausura
#
# Text: What is Calvin Mokoto's average rank?
# Pred SQL: <pad> SELECT AVG Rank FROM table WHERE Name = calvin mokot
# True SQL: SELECT AVG Rank FROM table WHERE Athletes = calvin mokoto
#
# Text: What is the home venue of essendon with a crowd larger than 19,760?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Crowd > 19,760 AND Home team =
# True SQL: SELECT Venue FROM table WHERE Crowd > 19,760 AND Home team = essendon
#
# Text: What is the birthday of caps of 32?
# Pred SQL: <pad> SELECT Birthday FROM table WHERE Caps = 32</s>
# True SQL: SELECT Date of Birth (Age) FROM table WHERE Caps = 32
#
# Text: When us open (2) is the championship what is the surface?
# Pred SQL: <pad> SELECT Surface FROM table WHERE Championship = US Open (2)</s>
# True SQL: SELECT Surface FROM table WHERE Championship = US Open (2)
#
# Text: How many endowments does Mosaic Stadium have?
# Pred SQL: <pad> SELECT COUNT Endowment FROM table WHERE Stadium = Mosaic Stadium
# True SQL: SELECT COUNT Endowment FROM table WHERE Football stadium = Mosaic Stadium
#
# Text: what are all the records with a score is w 98–91
# Pred SQL: <pad> SELECT Record FROM table WHERE Score = W 98–91</s>
# True SQL: SELECT Record FROM table WHERE Score = W 98–91
#
# Text: Which driver won the Phillip Island Grand Prix Circuit?
# Pred SQL: <pad> SELECT Driver FROM table WHERE Circuit = Phillip Island Grand Prix Circuit</s>
# True SQL: SELECT Winner FROM table WHERE Circuit = phillip island grand prix circuit
#
# Text: What year has Stacy as the category and award of Best Reality Star in Social Media?
# Pred SQL: <pad> SELECT Year FROM table WHERE Category = stacy AND Award = best
# True SQL: SELECT MIN Year FROM table WHERE Category = stacy AND Awards = best reality star in social media
#
# Text: What is the lowest top 5 winners with less than 0?
# Pred SQL: <pad> SELECT MIN Top 5 Winners FROM table WHERE Top 5 Winners
# True SQL: SELECT MIN Top-5 FROM table WHERE Wins < 0
#
# Text: What is the pick# from South Dakota college?
# Pred SQL: <pad> SELECT Pick # FROM table WHERE College = south dakota</s>
# True SQL: SELECT Pick # FROM table WHERE College = south dakota
#
# Text: Tell me the service for versions l-410uvp
# Pred SQL: <pad> SELECT Service FROM table WHERE Version = l-410uvp</s>
# True SQL: SELECT In service FROM table WHERE Versions = l-410uvp
#
# Text: Which player who played for the Rockets for the years 1986-92?
# Pred SQL: <pad> SELECT Player FROM table WHERE Years for Rockets = 1986-92</s>
# True SQL: SELECT Player FROM table WHERE Years for Rockets = 1986-92
#
# Text: What is the Sum of ERP W, when Call Sign is K216GA?
# Pred SQL: <pad> SELECT SUM ERP W FROM table WHERE Call sign = k216g
# True SQL: SELECT SUM ERP W FROM table WHERE Call sign = k216ga
#
# Text: what is the most tonnage grt of any ship sunk or captured on 16 jan 16?
# Pred SQL: <pad> SELECT MAX Tonnage grt FROM table WHERE Date sunk or
# True SQL: SELECT MAX Tonnage GRT FROM table WHERE Date = 16 jan 16
#
# Text: What is the mean Founded number when the team is the Baton Rouge Blaze?
# Pred SQL: <pad> SELECT AVG Founded FROM table WHERE Team = baton rouge blaze
# True SQL: SELECT AVG Founded FROM table WHERE Team = baton rouge blaze
#
# Text: What is the original air date of the episode written by Karen Felix and Don Woodard?
# Pred SQL: <pad> SELECT Original air date FROM table WHERE Written by = Karen Felix and Don Wood
# True SQL: SELECT Original air date FROM table WHERE Written by = Karen Felix and Don Woodard
#
# Text: Steve Nash (24) got high points for how many teams?
# Pred SQL: <pad> SELECT COUNT Team FROM table WHERE High points = Steve Nash (24)
# True SQL: SELECT COUNT Team FROM table WHERE High points = Steve Nash (24)
#
# Text: What is the lowest year in since that had a transfer fee of € 14m and ended after 2011?
# Pred SQL: <pad> SELECT MIN Year in since FROM table WHERE Transfer fee = € 14m
# True SQL: SELECT MIN Since FROM table WHERE Transfer fee = € 14m AND Ends > 2011
#
# Text: what is the population where the area (sq. mi.) is area (sq. mi.)?
# Pred SQL: <pad> SELECT Population FROM table WHERE Area (sq. mi.) = Area
# True SQL: SELECT Population FROM table WHERE Area (sq. mi.) = Area (sq. mi.)
#
# Text: When was the episode with a 999,000 BARB rating first aired in Denmark?
# Pred SQL: <pad> SELECT Original air date FROM table WHERE Rating = 999,000 BARB AND Country
# True SQL: SELECT First broadcast Denmark ( DR1 ) FROM table WHERE Official BARB ratings = 999,000
#
# Text: What is the weight of the player with a height of 2.00m?
# Pred SQL: <pad> SELECT Weight FROM table WHERE Height = 2.00m</s>
# True SQL: SELECT Weight FROM table WHERE Height = 2.00
#
# Text: What is the Hanzi of Phoenix Television Chinese that launched in 1996?
# Pred SQL: <pad> SELECT Hanzi FROM table WHERE Year launched = 1996 AND Language = chi
# True SQL: SELECT Hanzi FROM table WHERE Launch = 1996 AND Name = phoenix television chinese
#
# Text: Name the candidates for georgia 8
# Pred SQL: <pad> SELECT Candidates FROM table WHERE District = Georgia 8</s>
# True SQL: SELECT Candidates FROM table WHERE District = Georgia 8
#
# Text: What's the number of the game in which Carlos Boozer (8) did the high rebounds?
# Pred SQL: <pad> SELECT COUNT Game FROM table WHERE High rebounds = Carlos Boozer
# True SQL: SELECT Game FROM table WHERE High rebounds = Carlos Boozer (8)
#
# Text: Which 3rd run has rank of 8?
# Pred SQL: <pad> SELECT 3rd run FROM table WHERE Rank = 8</s>
# True SQL: SELECT 3rd run FROM table WHERE Rank = 8
#
# Text: What are the number of floors for the building of td building redevelopment (office)?
# Pred SQL: <pad> SELECT COUNT Floors FROM table WHERE Building = td building
# True SQL: SELECT AVG Floors FROM table WHERE Building = td building redevelopment (office)
#
# Text: What is the position of the team player from Aik?
# Pred SQL: <pad> SELECT Position FROM table WHERE School/Club Team = aik
# True SQL: SELECT Position FROM table WHERE Team from = aik
#
# Text: What position is number 35 whose height is 6-6?
# Pred SQL: <pad> SELECT Position FROM table WHERE Height = 6-6 AND No. = 35</s>
# True SQL: SELECT Position FROM table WHERE Height in Ft. = 6-6 AND No.(s) = 35
#
# Text: Which FCC info has an ERP W of 100 watts?
# Pred SQL: <pad> SELECT FCC info FROM table WHERE ERP W = 100 watts</s>
# True SQL: SELECT FCC info FROM table WHERE ERP W = 100 watts
#
# Text: How much Gain has a Long of 29, and an Avg/G smaller than 33.7?
# Pred SQL: <pad> SELECT SUM Gain FROM table WHERE Long = 29 AND Avg/
# True SQL: SELECT COUNT Gain FROM table WHERE Long = 29 AND Avg/G < 33.7
#
# Text: How many grids correspond to more than 24 laps?
# Pred SQL: <pad> SELECT COUNT Grid FROM table WHERE Laps > 24</s>
# True SQL: SELECT MAX Grid FROM table WHERE Laps > 24
#
# Text: What is the number of gold medals when the number of bronze medals is 8?
# Pred SQL: <pad> SELECT Gold FROM table WHERE Bronze = 8</s>
# True SQL: SELECT Gold FROM table WHERE Bronze = 8
#
# Text: What is the smallest number of field goals for players with 4 touchdowns and less than 9 extra points?
# Pred SQL: <pad> SELECT MIN Field goals FROM table WHERE Touchdowns = 4 AND Extra
# True SQL: SELECT MIN Field goals FROM table WHERE Touchdowns = 4 AND Extra points < 9
#
# Text: When thomas löfkvist is the  young rider classification and alessandro petacchi is the points classification who are the general classifications?
# Pred SQL: <pad> SELECT General classifications FROM table WHERE Points classification = alessandro
# True SQL: SELECT General classification FROM table WHERE Points classification = Alessandro Petacchi AND Young rider classification = Thomas Löfkvist
#
# Text: What is the Venue of the Competition with a Result of 2–2 (d)?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Result = 2–2 (d)</s>
# True SQL: SELECT Venue FROM table WHERE Result = 2–2 (d)
#
# Text: Which Engine has a Model of sl500, and a Chassis smaller than 129.067?
# Pred SQL: <pad> SELECT Engine FROM table WHERE Model = sl500 AND Chassis
# True SQL: SELECT MIN Engine FROM table WHERE Model = sl500 AND Chassis < 129.067
#
# Text: Can you tell me the average Weight that has Height of 6-9?
# Pred SQL: <pad> SELECT AVG Weight FROM table WHERE Height = 6-9</s>
# True SQL: SELECT AVG Weight FROM table WHERE Height = 6-9
#
# Text: What is the US air date when the director is ken girotti?
# Pred SQL: <pad> SELECT U.S. air date FROM table WHERE Director = ken
# True SQL: SELECT US air date FROM table WHERE Directed by = Ken Girotti
#
# Text: what is the weeks on chart for the single from france?
# Pred SQL: <pad> SELECT Weeks on Chart FROM table WHERE Country = france</s>
# True SQL: SELECT Weeks on chart FROM table WHERE Country = france
#
# Text: Which municipality has a population of 24421?
# Pred SQL: <pad> SELECT Municipality FROM table WHERE Population = 24421</s>
# True SQL: SELECT Municipality FROM table WHERE Population = 24421
#
# Text: Record of 21–29–10 had what total number of points?
# Pred SQL: <pad> SELECT COUNT Points FROM table WHERE Record = 21–29–10
# True SQL: SELECT COUNT Points FROM table WHERE Record = 21–29–10
#
# Text: What game 1 has halfback as a position?
# Pred SQL: <pad> SELECT Game 1 FROM table WHERE Position = halfback</s>
# True SQL: SELECT Game 1 FROM table WHERE Position = halfback
#
# Text: What year saw an award in the category of Revelation?
# Pred SQL: <pad> SELECT Year FROM table WHERE Category = Revelation</s>
# True SQL: SELECT Year FROM table WHERE Category = revelation
#
# Text: What nationality has steve kerr as the player?
# Pred SQL: <pad> SELECT Nationality FROM table WHERE Player = steve kerr</s>
# True SQL: SELECT Nationality FROM table WHERE Player = steve kerr
#
# Text: What's the total compulsory when the total is more than 69.2 and the voluntary is 38.7?
# Pred SQL: <pad> SELECT COUNT Compulsory FROM table WHERE Total > 69
# True SQL: SELECT COUNT Compulsory FROM table WHERE Voluntary = 38.7 AND Total > 69.2
#
# Text: What is the average for matches with a prize money amount of £3,000?
# Pred SQL: <pad> SELECT AVG Matches FROM table WHERE Prize money = £3,000</s>
# True SQL: SELECT AVG Matches FROM table WHERE Prize money = £3,000
#
# Text: Which Year is the highest one that has a Bronze of south korea, and a Silver of philippines?
# Pred SQL: <pad> SELECT MAX Year FROM table WHERE Bronze = south korea AND
# True SQL: SELECT MAX Year FROM table WHERE Bronze = south korea AND Silver = philippines
#
# Text: what is the Power with 88.5 fm Frequency
# Pred SQL: <pad> SELECT Power FROM table WHERE Frequency = 88.5 fm</s>
# True SQL: SELECT Power FROM table WHERE Frequency = 88.5 fm
#
# Text: When aaron brooks (6) had the highest amount of assists what is the date?
# Pred SQL: <pad> SELECT Date FROM table WHERE High assists = Aaron Brooks (6)</s>
# True SQL: SELECT Date FROM table WHERE High assists = Aaron Brooks (6)
#
# Text: What was the total number of Points when the value Difference was 13, and when the value Lost was greater than 3?
# Pred SQL: <pad> SELECT COUNT Points FROM table WHERE Difference = 13 AND Lost > 3
# True SQL: SELECT SUM Points FROM table WHERE Difference = 13 AND Lost > 3
#
# Text: What were the results before the year 2000?
# Pred SQL: <pad> SELECT Result FROM table WHERE Year <unk> 2000</s>
# True SQL: SELECT Result FROM table WHERE Year < 2000
#
# Text: What is the Pick # for Ryan Strong?
# Pred SQL: <pad> SELECT Pick # FROM table WHERE Player = ryan strong</s>
# True SQL: SELECT MAX Pick # FROM table WHERE Player = ryan strong
#
# Text: At a longitude of 109.9e, how many features were found?
# Pred SQL: <pad> SELECT COUNT Feature FROM table WHERE Longitude = 109.9
# True SQL: SELECT COUNT Diameter (km) FROM table WHERE Longitude = 109.9E
#
# Text: If the Away team is north melbourne, what's the Home team score?
# Pred SQL: <pad> SELECT Home team score FROM table WHERE Away team = north melbourne
# True SQL: SELECT Home team score FROM table WHERE Away team = north melbourne
#
# Text: What is the 35mm EFL and the equivalent aperture of the lens(es) with a maximum aperture of f /2.5?
# Pred SQL: <pad> SELECT EFL 35mm FROM table WHERE Maximum aperture = f /
# True SQL: SELECT 35mm EFL and equivalent aperture FROM table WHERE Max. aperture = f /2.5
#
# Text: What is the result of the game at three rivers stadium with a Record of 6–3?
# Pred SQL: <pad> SELECT Result FROM table WHERE Game site = three rivers stadium AND Record =
# True SQL: SELECT Result FROM table WHERE Location = three rivers stadium AND Record = 6–3
#
# Text: What is latitude when 2010 population is 24 and water is more than 0.319?
# Pred SQL: <pad> SELECT Latitude FROM table WHERE 2010 Population = 24 AND Water (m)
# True SQL: SELECT MAX Latitude FROM table WHERE Pop. (2010) = 24 AND Water (sqmi) > 0.319
#
# Text: What is the sum of NGC numbers for Constellation vela?
# Pred SQL: <pad> SELECT SUM NGC number FROM table WHERE Name = constellation vela
# True SQL: SELECT SUM NGC number FROM table WHERE Constellation = vela
#
# Text: Which opponent has a loss of wells (1-3)?
# Pred SQL: <pad> SELECT Opponent FROM table WHERE Loss = wells (1-3)</s>
# True SQL: SELECT Opponent FROM table WHERE Loss = wells (1-3)
#
# Text: What is the lowest Crowd with a Home Team Score of 9.15 (69)?
# Pred SQL: <pad> SELECT MIN Crowd FROM table WHERE Home team score = 9.15 (
# True SQL: SELECT MIN Crowd FROM table WHERE Home team score = 9.15 (69)
#
# Text: What nationality is keith carney?
# Pred SQL: <pad> SELECT Nationality FROM table WHERE Player = Keith Carney</s>
# True SQL: SELECT Nationality FROM table WHERE Player = Keith Carney
#
# Text: What is the club or province of Girvan Dempsey, who has 74 caps?
# Pred SQL: <pad> SELECT Club/province FROM table WHERE Caps = 74 AND
# True SQL: SELECT Club/province FROM table WHERE Caps = 74 AND Player = girvan dempsey
#
# Text: What was the final score on week 14 ?
# Pred SQL: <pad> SELECT Score FROM table WHERE Week = 14</s>
# True SQL: SELECT Final Score FROM table WHERE Week = 14
#
# Text: Which venue has more than 19 against?
# Pred SQL: <pad> SELECT Venue FROM table WHERE Against > 19</s>
# True SQL: SELECT Venue FROM table WHERE Against > 19
#
# Text: What was the result of the game that was played on week 15?
# Pred SQL: <pad> SELECT Result FROM table WHERE Week = 15</s>
# True SQL: SELECT Result FROM table WHERE Week = 15
#
# Text: Which publisher has Far Cry as the title?
# Pred SQL: <pad> SELECT Publisher FROM table WHERE Title = far cry</s>
# True SQL: SELECT Publisher FROM table WHERE Title = far cry
#
# Text: In 2004, where the womens singles is daniela kressig who is the mens singles
# Pred SQL: <pad> SELECT Mens singles FROM table WHERE Womens singles = Daniela
# True SQL: SELECT Mens singles FROM table WHERE Womens singles = Daniela Kressig
#
# Text: When was the year that had an average attendance of 5,445?
# Pred SQL: <pad> SELECT Year FROM table WHERE Average Attendance = 5,445</s>
# True SQL: SELECT Year FROM table WHERE Avg. attendance = 5,445
#
# Text: What is the average Round for wide receiver r. jay soward and Overall smaller than 29?
# Pred SQL: <pad> SELECT AVG Round FROM table WHERE Position = wide receiver AND Overall <unk>
# True SQL: SELECT AVG Round FROM table WHERE Position = wide receiver AND Name = r. jay soward AND Overall < 29
#
# Text: Name the first season in the series for 2006
# Pred SQL: <pad> SELECT First season FROM table WHERE Season = 2006</s>
# True SQL: SELECT First season in the Serie A FROM table WHERE Last title = 2006
#
# Text: What was the religious affiliation for the athletics nicknamed lords/ladies?
# Pred SQL: <pad> SELECT Religious Affiliation FROM table WHERE Athletics Nickname =
# True SQL: SELECT Religious affiliation FROM table WHERE Athletics nickname = lords/ladies
#
# Text: Which capital has a Hangul of 경상남도?
# Pred SQL: <pad> SELECT Capital FROM table WHERE Hangul = <unk></s>
# True SQL: SELECT Capital FROM table WHERE Hangul/Chosongul = 경상남도
#
# Text: The new entries this round was shown to be 12, in which phase would you find this?
# Pred SQL: <pad> SELECT Phase FROM table WHERE New entries this round = 12</s>
# True SQL: SELECT Phase FROM table WHERE New entries this round = 12
#
# Text: What opponent had an attendance of 10,089?
# Pred SQL: <pad> SELECT Opponent FROM table WHERE Attendance = 10,089</s>
# True SQL: SELECT Opponent FROM table WHERE Attendance = 10,089
#
# Text: Name the distrct for thomas wilson
# Pred SQL: <pad> SELECT Distribution FROM table WHERE Driver = Thomas Wilson</s>
# True SQL: SELECT District FROM table WHERE Incumbent = Thomas Wilson
#
# Text: What is the tie no of the game where exeter city was the home team?
# Pred SQL: <pad> SELECT Tie no FROM table WHERE Home team = exeter city</s>
# True SQL: SELECT Tie no FROM table WHERE Home team = exeter city

# %% [markdown]
# # **Translate FR to ENG**

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-small')

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
books = load_dataset("opus_books", "en-fr")
# Out:
# WARNING:datasets.builder:Found cached dataset opus_books (/root/.cache/huggingface/datasets/opus_books/en-fr/1.0.0/e8f950a4f32dc39b7f9088908216cd2d7e21ac35f893d04d39eb594746af2daf)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
books = books["train"].train_test_split(test_size=0.2)

# %%
books["train"][0]
# Out:
# {'id': '46701',
#  'translation': {'en': '"Why, then," cried Milady, with an incredible tone of truthfulness, "you are not his accomplice; you do not know that he destines me to a disgrace which all the punishments of the world cannot equal in horror?"',
#   'fr': "-- Mais, s'écria Milady avec un incroyable accent de vérité, vous n'êtes donc pas son complice, vous ne savez donc pas qu'il me destine à une honte que tous les châtiments de la terre ne sauraient égaler en horreur?"}}

# %%
# !pip install transformers

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (0.1.97)

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("t5-small")

# %%
source_lang = "fr"
target_lang = "en"
prefix = "translate French to English: "

# %%
def preprocess_function(examples):
    inputs = [prefix + example[source_lang] for example in examples["translation"]]
    targets = [example[target_lang] for example in examples["translation"]]
    model_inputs = tokenizer(inputs, text_target=targets, max_length=128, truncation=True)
    return model_inputs

# %%
tokenized_books = books.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/102 [00:00<?, ?ba/s]
#   0%|          | 0/26 [00:00<?, ?ba/s]

# %%
tokenized_books
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 101668
#     })
#     test: Dataset({
#         features: ['id', 'translation', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 25417
#     })
# })

# %%
from transformers import AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer

training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=1,
    #fp16=True,
)

trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_books["train"],
    eval_dataset=tokenized_books["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)

trainer.train()

# %%
#sentences = ["The house is wonderful.", "I like to work in NYC."]
sentences = ["Jes suis Hassan.", "Je suis Hassan."]

inputs = tokenizer([prefix + sentence for sentence in sentences], return_tensors="pt", padding=True)

# %%
output_sequences = model.generate(
    input_ids=inputs["input_ids"],
    attention_mask=inputs["attention_mask"],
    do_sample=False,  # disable sampling to test if batching affects output
)

print(tokenizer.batch_decode(output_sequences, skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# ['Jes suis Hassan.', 'Je suis Hassan.']

# %% [markdown]
# # **FR to EN translation using deep_translator**

# %%
# !pip install deep-translator
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deep-translator
#   Downloading deep_translator-1.9.1-py3-none-any.whl (30 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1
#   Downloading beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 20.3 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from deep-translator) (2.23.0)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.25.11)
# Installing collected packages: soupsieve, beautifulsoup4, deep-translator
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.11.1 deep-translator-1.9.1 soupsieve-2.3.2.post1

# %%
from deep_translator import GoogleTranslator
to_translate = "Quelle est l'age de la personne Hassan"
translated = GoogleTranslator(source='auto', target='en').translate(to_translate)

# %%
translated
# Out:
# 'How old is the person Hassan'

# %%
get_sql(to_translate)
# Out:
# '<pad> SELECT Age FROM table WHERE Name = hassan</s>'
